# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Pivot Tables

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    462     97   John  January      Q1
# 1  2023-01-02       B   West    643     34   Mary  January      Q1
# 2  2023-01-03       C  North    606     65    Bob  January      Q1
# 3  2023-01-04       D  South    121     66  Alice  January      Q1
# 4  2023-01-05       A   East    694     89   John  January      Q1
# 5  2023-01-06       B   West    893     92   Mary  January      Q1
# 6  2023-01-07       C  North    912     83    Bob  January      Q1
# 7  2023-01-08       D  South    356     14  Alice  January      Q1
# 8  2023-01-09       A   East    459     73   John  January      Q1
# 9  2023-01-10       B   West    202     99   Mary  January      Q1
# 10 2023-01-11       C  North    812     34    Bob  January      Q1
# 11 2023-01-12       D  South    450     99  Alice  January      Q1
# 12 2023-01-13       A   East    633     78   John  January      Q1
# 13 2023-01-14       B   West    312     88   Mary  January      Q1
# 14 2023-01-15       C  North    377     91    Bob  January      Q1
# 15 2023-01-16       D  South    615     76  Alice  January      Q1
# 16 2023-01-17       A   East    395     69   John  January      Q1
# 17 2023-01-18       B   West    959     80   Mary  January      Q1
# 18 2023-01-19       C  North    293     47    Bob  January      Q1
# 19 2023-01-20       D  South    581     15  Alice  January      Q1

# %%
pd.pivot_table(df , values = 'Sales' , index = 'Region' , columns = 'Product' , aggfunc = 'sum' )
# Out:
# Product       A       B       C       D
# Region
# East     2643.0     NaN     NaN     NaN
# North       NaN     NaN  3000.0     NaN
# South       NaN     NaN     NaN  2123.0
# West        NaN  3009.0     NaN     NaN

# %%
pd.pivot_table(df, index='Product', columns='Region', values= ['Sales' , 'Units'], aggfunc='sum')
# Out:
#           Sales                          Units
# Region     East   North   South    West   East  North  South   West
# Product
# A        2643.0     NaN     NaN     NaN  406.0    NaN    NaN    NaN
# B           NaN     NaN     NaN  3009.0    NaN    NaN    NaN  393.0
# C           NaN  3000.0     NaN     NaN    NaN  320.0    NaN    NaN
# D           NaN     NaN  2123.0     NaN    NaN    NaN  270.0    NaN
